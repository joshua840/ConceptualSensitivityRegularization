# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
ldr = os.listdir('/media/disk1/Data/SpuriousCatDogVer3/')

# %%
[i for i in ldr if 'csv' in i]
# Out:
# ['metadata_catdog2.csv', 'metadata.csv']

# %%
df = pd.read_csv('/media/disk1/Data/SpuriousCatDogVer3/metadata_catdog2.csv')

# %%
df
# Out:
#       index               fg_filename            species  y  split  place  \
# 0         0          Abyssinian_1.jpg         Abyssinian  0  train      0
# 1         1         Abyssinian_10.jpg         Abyssinian  0  train      0
# 2         2        Abyssinian_100.jpg         Abyssinian  0  train      0
# 3         3        Abyssinian_101.jpg         Abyssinian  0  train      0
# 4         4        Abyssinian_102.jpg         Abyssinian  0  train      0
# ...     ...                       ...                ... ..    ...    ...
# 8863   7360  yorkshire_terrier_72.jpg  yorkshire_terrier  1   test      1
# 8864   7364  yorkshire_terrier_76.jpg  yorkshire_terrier  1   test      1
# 8865   7367  yorkshire_terrier_79.jpg  yorkshire_terrier  1   test      1
# 8866   7372  yorkshire_terrier_83.jpg  yorkshire_terrier  1   test      1
# 8867   7376  yorkshire_terrier_87.jpg  yorkshire_terrier  1   test      1
#
#                                         place_filename  \
# ...

# %%
df2 = pd.read_csv('/media/disk1/Data/SpuriousCatDogVer3/metadata.csv')

# %%
df2
# Out:
#                                                filename  split  y  a
# 0     Abyssinian_1_gsun_000000a90e084bef1674997d879b...      0  0  0
# 1     Abyssinian_10_gsun_00002631f4ffd977e8abc8d5b13...      0  0  0
# 2     Abyssinian_100_gsun_00067b2e24505cb7d026724039...      0  0  0
# 3     Abyssinian_101_gsun_00130f6df09e57028f387f3c12...      0  0  0
# 4     Abyssinian_102_gsun_0013e19bc3c42c0120c21f4475...      0  0  0
# ...                                                 ...    ... .. ..
# 8863  yorkshire_terrier_72_gsun_c79ece34c6697cdea6b4...      2  1  1
# 8864  yorkshire_terrier_76_gsun_c7b93a6affb42232ad77...      2  1  1
# 8865  yorkshire_terrier_79_gsun_c7baba51dcf5f38897c8...      2  1  1
# 8866  yorkshire_terrier_83_gsun_c7baf88893658d9dfb74...      2  1  1
# 8867  yorkshire_terrier_87_gsun_c7c2c903d6164485088c...      2  1  1
#
# [8868 rows x 4 columns]

# %%
df3 = pd.read_csv('/media/disk1/Data/waterbirds/waterbird_complete95_forest2water2/metadata.csv')

# %%
df3
# Out:
#        img_id                                       img_filename  y  split  \
# 0           1  001.Black_footed_Albatross/Black_Footed_Albatr...  1      2
# 1           2  001.Black_footed_Albatross/Black_Footed_Albatr...  1      0
# 2           3  001.Black_footed_Albatross/Black_Footed_Albatr...  1      2
# 3           4  001.Black_footed_Albatross/Black_Footed_Albatr...  1      0
# 4           5  001.Black_footed_Albatross/Black_Footed_Albatr...  1      0
# ...       ...                                                ... ..    ...
# 11783   11784  200.Common_Yellowthroat/Common_Yellowthroat_00...  0      0
# 11784   11785  200.Common_Yellowthroat/Common_Yellowthroat_00...  0      2
# 11785   11786  200.Common_Yellowthroat/Common_Yellowthroat_00...  0      2
# 11786   11787  200.Common_Yellowthroat/Common_Yellowthroat_00...  0      0
# 11787   11788  200.Common_Yellowthroat/Common_Yellowthroat_00...  0      2
#
#        place                    place_filename
# ...

# %%
df4 = pd.read_csv('/media/disk1/Data/waterbirds/waterbird_complete95_forest2water2/metadata_waterbirds.csv')

# %%
df4
# Out:
#           id                                           filename  split  y  a
# 0          1  001.Black_footed_Albatross/Black_Footed_Albatr...      2  1  1
# 1          2  001.Black_footed_Albatross/Black_Footed_Albatr...      0  1  1
# 2          3  001.Black_footed_Albatross/Black_Footed_Albatr...      2  1  0
# 3          4  001.Black_footed_Albatross/Black_Footed_Albatr...      0  1  1
# 4          5  001.Black_footed_Albatross/Black_Footed_Albatr...      0  1  1
# ...      ...                                                ...    ... .. ..
# 11783  11784  200.Common_Yellowthroat/Common_Yellowthroat_00...      0  0  0
# 11784  11785  200.Common_Yellowthroat/Common_Yellowthroat_00...      2  0  0
# 11785  11786  200.Common_Yellowthroat/Common_Yellowthroat_00...      2  0  0
# 11786  11787  200.Common_Yellowthroat/Common_Yellowthroat_00...      0  0  0
# 11787  11788  200.Common_Yellowthroat/Common_Yellowthroat_00...      2  0  1
#
# [11788 rows x 5 columns]
