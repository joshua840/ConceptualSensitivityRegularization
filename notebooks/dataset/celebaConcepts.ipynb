# %%
# %cd ../..
# Out:
# /home/jj/Research/ConceptualSensitivityRegularization

# %% [markdown]
# ### Investigating `minor_ratio` in Waterbirds module

# %%
from csr.module.dataset.concept_dataset import ConceptDataset
import os
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import transforms

root = '/media/disk1/Data/celeba'

transform_ = transforms.Compose(
    [
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    ]
)

dataset_train = ConceptDataset(root=os.path.join(root), dataset='celeba_collar_concepts_v2', model_name='convnect_t', transform=transform_)


# plot some images (2*5)
for x, y, _, _ in DataLoader(dataset_train, batch_size=128, num_workers=20, shuffle=True):
    x = x[:20]
    y = y[:20]
    break

fig, axs = plt.subplots(2, 10, figsize=(20, 4))
for i, ax in enumerate(axs.flatten()):
    img = x[i].permute(1, 2, 0)
    # unnormalize image
    img = img * torch.tensor([0.229, 0.224, 0.225]) + torch.tensor([0.485, 0.456, 0.406])
    ax.imshow(img)
    ax.set_title(f'{y[i]}')
    ax.axis('off')
plt.show()

# %%
dataset_train.samples
# Out:
# [('000152.jpg', 0),
#  ('011039.jpg', 0),
#  ('022880.jpg', 0),
#  ('038838.jpg', 0),
#  ('058416.jpg', 0),
#  ('067931.jpg', 0),
#  ('080909.jpg', 0),
#  ('099917.jpg', 0),
#  ('121761.jpg', 0),
#  ('131876.jpg', 0),
#  ('140783.jpg', 0),
#  ('153566.jpg', 0),
#  ('163187.jpg', 0),
#  ('171482.jpg', 0),
#  ('183994.jpg', 0),
#  ('196721.jpg', 0),
#  ('000071.jpg', 1),
#  ('000111.jpg', 1),
#  ('000141.jpg', 1),
#  ('000191.jpg', 1),
#  ('000201.jpg', 1),
#  ('000271.jpg', 1),
#  ('000291.jpg', 1),
#  ('000341.jpg', 1),
#  ('000351.jpg', 1),
#  ('000371.jpg', 1),
#  ('000431.jpg', 1),
#  ('000471.jpg', 1),
#  ('000691.jpg', 1),
#  ('000721.jpg', 1),
#  ('000751.jpg', 1),
#  ('000871.jpg', 1),
#  ('000941.jpg', 1),
#  ('001091.jpg', 1),
#  ('001261.jpg', 1),
#  ('001271.jpg', 1),
#  ('001341.jpg', 1),
#  ('001371.jpg', 1),
#  ('001391.jpg', 1),
#  ('001881.jpg', 1),
#  ('001901.jpg', 1),
#  ('002251.jpg', 1),
#  ('002261.jpg', 1),
#  ('002271.jpg', 1),
#  ('002401.jpg', 1),
# ...
